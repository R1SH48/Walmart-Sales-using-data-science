# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
file_path = './Walmart_Sales.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
plt.plot(df['Weekly_Sales'])

# %%
x=df['Weekly_Sales'].values
result = adfuller(x)
print('ADF Statistic : %f' %result[0])
print('p-value : %f' %result[1])
print('Critical Values :')
for key, value in result[4].items():
    print('\t%s : %.3f' % (key, value))

if(result[0]<result[4]['5%']):
    print('Reject hypothesis - Time series is stationary')
else:
    print('Failed to reject hypothesis - Time series is non-stationary')

#ADF statistics > critical value -> time series is non stationary
# Out:
# ADF Statistic : -4.624149
# p-value : 0.000117
# Critical Values :
# 	1% : -3.431
# 	5% : -2.862
# 	10% : -2.567
# Reject hypothesis - Time series is stationary

# %%
df['Diff_Sales'] = df['Weekly_Sales'].diff()

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  Diff_Sales
# 0  211.096358         8.106         NaN
# 1  211.242170         8.106    -1733.46
# 2  211.289143         8.106   -29989.27
# 3  211.319643         8.106  -202240.58
# 4  211.350143         8.106   145079.09

# %%
plt.plot(df['Diff_Sales'])

# %%
diff_sales = df['Diff_Sales'].values
Y = diff_sales[~np.isnan(diff_sales)]

# %%
ts_sales_origin = df['Weekly_Sales'].values
ts_sales = ts_sales_origin[:-1]

# %%
X = sm.add_constant(ts_sales)

# %%
model=sm.OLS(Y,X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     181.7
# Date:                Tue, 25 Jun 2024   Prob (F-statistic):           7.21e-41
# Time:                        16:11:15   Log-Likelihood:                -87137.
# No. Observations:                6434   AIC:                         1.743e+05
# Df Residuals:                    6432   BIC:                         1.743e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.734e+04   4843.045     11.839      0.000    4.78e+04    6.68e+04
# ...
